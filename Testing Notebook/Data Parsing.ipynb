# %% [markdown]
# # Data Parsing
#
# ## The following cells will be debugging and development for a data parsing script utilizing pandas and system commands to access, create, and organize files.

# %%
import pandas as pd, datetime, glob, os

# %%
custom_date_parser = lambda x,y,z,a,b: datetime.datetime.strptime(f"{x} {y} {z} {a} {b}", "%Y %m %d %H %M")

# %%
data_dir = f"..\\Data\\"

# %%
display_file = pd.read_csv("../Solar Data/02220c7425e608d72fceb5de4f3da6eb/02220c7425e608d72fceb5de4f3da6eb/24_18.40_-67.25_2016.csv", header=[2],parse_dates={'Date':[0,1,2,3,4]},date_parser=custom_date_parser)
display_file2 = pd.read_csv("../Solar Data/02220c7425e608d72fceb5de4f3da6eb/02220c7425e608d72fceb5de4f3da6eb/24_18.40_-67.25_2016.csv", nrows=1)
display_file3 = pd.read_csv("../Solar Data/02220c7425e608d72fceb5de4f3da6eb/02220c7425e608d72fceb5de4f3da6eb/25_18.38_-67.25_2016.csv", header=[2],parse_dates={'Date':[0,1,2,3,4]},date_parser=custom_date_parser)
display_file4 = pd.read_csv("../Solar Data/02220c7425e608d72fceb5de4f3da6eb/02220c7425e608d72fceb5de4f3da6eb/25_18.38_-67.25_2016.csv", nrows=1)
display_file["Latitude"] = display_file2.Latitude[0]
display_file["Longitude"] = display_file2.Longitude[0]
display_file3["Latitude"] = display_file4.Latitude[0]
display_file3["Longitude"] = display_file4.Longitude[0]
test_df = pd.concat([display_file,display_file3])
test_df
test_group_df = test_df.groupby([pd.Grouper(key="Date", freq='1D'),"Latitude","Longitude"]).mean()
test_group_df
# desired_output = pd.read_csv("../Solar Data/INSOLRICO.2021302.csv", delim_whitespace=True,names=["value","latitude","longitude"])

# %%
year = "2018"
files = glob.glob(f"../NREL Data/**/*{year}.csv",recursive=True)
print(files)

# %%
Year = "2019"
BigDF = pd.DataFrame()
dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
#Store all of the files as a list, in order to access it in the loop appropriately. 
files = glob.glob(f"../NREL Data/**/*{year}.csv",recursive=True)
for index in range(0,len(files)):
    if len(files)>2:
        DataFile = files.pop()
        DataFile2 = files.pop()
        Csv_DF = pd.read_csv(DataFile, header=[2], parse_dates={'Date': [0, 1, 2, 3, 4]}, 
                             date_parser=dateparse)
        Lat_Lon_DF1 = pd.read_csv(DataFile, nrows=1)
        Csv_DF["Longitude"] = Lat_Lon_DF1.Longitude[0]
        Csv_DF["Latitude"] = Lat_Lon_DF1.Latitude[0]
        Csv_DF2 = pd.read_csv(DataFile2, header=[2], parse_dates={
                              'Date': [0, 1, 2, 3, 4]}, date_parser=dateparse)
        Lat_Lon_DF2 = pd.read_csv(DataFile2, nrows=1)
        Csv_DF2["Longitude"] = Lat_Lon_DF2.Longitude[0]
        Csv_DF2["Latitude"] = Lat_Lon_DF2.Latitude[0]
        BigDF = BigDF.append([Csv_DF,Csv_DF2])
    elif len(files)==1:
        DataFile = files.pop()
        Csv_DF = pd.read_csv(DataFile, header=[2], parse_dates={
                             'Date': [0, 1, 2, 3, 4]}, date_parser=dateparse)
        Lat_Lon_DF1 = pd.read_csv(DataFile, nrows=1)
        Csv_DF["Longitude"] = Lat_Lon_DF1.Longitude[0]
        Csv_DF["Latitude"] = Lat_Lon_DF1.Latitude[0]
        BigDF = BigDF.append([Csv_DF])

Parsed_Data = BigDF.groupby([pd.Grouper(key="Date", freq='1D'),"Latitude","Longitude"]).mean()
Parsed_Data = Parsed_Data.round(2)
# Out:
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# C:\Users\viaje\AppData\Local\Temp/ipykernel_9432/2509024558.py:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Users\viaje\anaconda3\envs\solarData\lib\site-packages\pandas\io\parsers\base_parser.py in converter(*date_cols)
#    1038                 result = tools.to_datetime(
# -> 1039                     date_parser(*date_cols), errors="ignore", cache=cache_dates
#    1040                 )
#
# TypeError: <lambda>() takes 1 positional argument but 5 were given
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9432/2509024558.py in <module>
#      13         Csv_DF["Longitude"] = Lat_Lon_DF1.Longitude[0]
#      14         Csv_DF["Latitude"] = Lat_Lon_DF1.Latitude[0]
# ---> 15         Csv_DF2 = pd.read_csv(DataFile2, header=[2], parse_dates={
#      16                               'Date': [0, 1, 2, 3, 4]}, date_parser=dateparse)
#      17         Lat_Lon_DF2 = pd.read_csv(DataFile2, nrows=1)
#
# D:\Users\viaje\anaconda3\envs\solarData\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# D:\Users\viaje\anaconda3\envs\solarData\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# D:\Users\viaje\anaconda3\envs\solarData\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# D:\Users\viaje\anaconda3\envs\solarData\lib\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# D:\Users\viaje\anaconda3\envs\solarData\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in read(self, nrows)
#     306             data = {k: v for k, (i, v) in zip(names, data_tups)}
#     307
# --> 308             names, data = self._do_date_conversions(names, data)
#     309             index, names = self._make_index(data, alldata, names)
#     310
#
# D:\Users\viaje\anaconda3\envs\solarData\lib\site-packages\pandas\io\parsers\base_parser.py in _do_date_conversions(self, names, data)
#     793
#     794         if self.parse_dates is not None:
# --> 795             data, names = _process_date_conversion(
#     796                 data,
#     797                 self._date_conv,
#
# D:\Users\viaje\anaconda3\envs\solarData\lib\site-packages\pandas\io\parsers\base_parser.py in _process_date_conversion(data_dict, converter, parse_spec, index_col, index_names, columns, keep_date_col)
#    1108                 raise ValueError(f"Date column {new_name} already in dict")
#    1109
# -> 1110             _, col, old_names = _try_convert_dates(
#    1111                 converter, colspec, data_dict, orig_names
#    1112             )
#
# D:\Users\viaje\anaconda3\envs\solarData\lib\site-packages\pandas\io\parsers\base_parser.py in _try_convert_dates(parser, colspec, data_dict, columns)
#    1142     to_parse = [data_dict[c] for c in colnames if c in data_dict]
#    1143
# -> 1144     new_col = parser(*to_parse)
#    1145     return new_name, new_col, colnames
#    1146
#
# D:\Users\viaje\anaconda3\envs\solarData\lib\site-packages\pandas\io\parsers\base_parser.py in converter(*date_cols)
#    1045                 try:
#    1046                     return tools.to_datetime(
# -> 1047                         parsing.try_parse_dates(
#    1048                             parsing.concat_date_cols(date_cols),
#    1049                             parser=date_parser,
#
# D:\Users\viaje\anaconda3\envs\solarData\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.try_parse_dates()
#
# ~\AppData\Local\Temp/ipykernel_9432/2509024558.py in <lambda>(x)
#       1 Year = "2019"
#       2 BigDF = pd.DataFrame()
# ----> 3 dateparse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')
#       4 #Store all of the files as a list, in order to access it in the loop appropriately.
#       5 files = glob.glob(f"../NREL Data/**/*{year}.csv",recursive=True)
#
# D:\Users\viaje\anaconda3\envs\solarData\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# D:\Users\viaje\anaconda3\envs\solarData\lib\_strptime.py in _strptime(data_string, format)
#     382             else:
#     383                 year += 1900
# --> 384         elif group_key == 'Y':
#     385             year = int(found_dict['Y'])
#     386         elif group_key == 'G':
#
# KeyboardInterrupt:

# %%
Parsed_Data
# Out:
#                                   GHI     DNI  Wind Speed  Temperature  \
# Date       Latitude Longitude
# 2018-01-01 17.90    -67.29     192.76  233.41        5.30        27.01
#                     -67.27     194.66  240.15        5.29        27.01
#                     -67.25     194.26  235.79        5.25        27.00
#                     -67.23     195.14  237.35        5.21        27.00
#                     -67.21     194.08  235.22        5.15        27.00
# ...                               ...     ...         ...          ...
# 2018-12-31 18.52    -66.47     198.10  271.25        4.67        26.32
#                     -66.45     200.28  277.00        4.67        26.31
#                     -66.43     200.07  273.59        4.66        26.30
#                     -66.41     206.68  289.26        4.66        26.29
#                     -66.39     199.67  272.19        4.65        26.29
#
#                                Relative Humidity
# Date       Latitude Longitude
# 2018-01-01 17.90    -67.29                 79.55
#                     -67.27                 79.45
#                     -67.25                 79.36
#                     -67.23                 79.27
#                     -67.21                 79.13
# ...                                          ...
# 2018-12-31 18.52    -66.47                 73.96
#                     -66.45                 73.96
#                     -66.43                 73.97
#                     -66.41                 73.96
#                     -66.39                 73.93
#
# [1051565 rows x 5 columns]

# %%
expected_date = datetime.date(int(Year), 1, 1)
day_offset = datetime.timedelta(days=1)
Values_To_Parse = ["GHI", "DNI", "Wind Speed", "Temperature", "Relative Humidity"]
for Value in Values_To_Parse:
    Data = pd.DataFrame(columns=['value', 'latitude', 'longitude'])
    for rowIndex, row in Parsed_Data.iterrows():
        if rowIndex[0].date() == expected_date:
            Data = Data.append({'value': row[Value], 'latitude': 
                rowIndex[1], 'longitude': rowIndex[2]}, ignore_index=True)
        elif expected_date.year > rowIndex[0].date().year and expected_date.day >= 1:
            expected_date = datetime.date(int(Year),1,1)
            continue
        else:
            Data.to_csv(
                path_or_buf=f"{data_dir}{rowIndex[0].strftime('%Y')}{Value}/{Value}{expected_date.strftime('%Y%j')}.csv", 
                header=False, index=False, sep=' ')
            Data.drop(index=Data.index, inplace=True)
            expected_date = expected_date+day_offset
    print(Data)

# %%
rand_date = datetime.date(2018,1,1)
day_offset = datetime.timedelta(days=1)
Parsed_Data.index[0][0].date()

# %%
year = "2018"
BigDF = pd.DataFrame()
files = glob.glob(f"../Solar Data/**/*{year}.csv",recursive=True)
for index in range(0,len(files)):
    if len(files)>2:
        DataFile = files.pop()
        DataFile2 = files.pop()
        CSV_DF = pd.read_csv(DataFile,header=[2],parse_dates={'Date':[0,1,2,3,4]},date_parser=custom_date_parser)
        Lat_Lon_DF1 = pd.read_csv(DataFile, nrows=1)
        CSV_DF["Longitude"] = Lat_Lon_DF1.Longitude[0]
        CSV_DF["Latitude"] = Lat_Lon_DF1.Latitude[0]
        CSV_DF2 = pd.read_csv(DataFile2,header=[2],parse_dates={'Date':[0,1,2,3,4]},date_parser=custom_date_parser)
        Lat_Lon_DF2 = pd.read_csv(DataFile2, nrows=1)
        CSV_DF2["Longitude"] = Lat_Lon_DF2.Longitude[0]
        CSV_DF2["Latitude"] = Lat_Lon_DF2.Latitude[0]
        BigDF = BigDF.append([CSV_DF,CSV_DF2])
    elif len(files)==1:
        DataFile = files.pop()
        CSV_DF = pd.read_csv(DataFile,header=[2],parse_dates={'Date':[0,1,2,3,4]},date_parser=custom_date_parser)
        Lat_Lon_DF1 = pd.read_csv(DataFile, nrows=1)
        CSV_DF["Longitude"] = Lat_Lon_DF1.Longitude[0]
        CSV_DF["Latitude"] = Lat_Lon_DF1.Latitude[0]
        BigDF = BigDF.append([CSV_DF])
else:
    print(len(files))
    BigDF = BigDF.groupby([pd.Grouper(key="Date", freq='1D'),"Latitude","Longitude"]).mean()
# Out:
# D:\Users\viaje\anaconda3\envs\solarData\lib\site-packages\pandas\io\parsers\base_parser.py:1055: FutureWarning:
#         Use pd.to_datetime instead.
#
#   return generic_parser(date_parser, *date_cols)
# 2

# %%
BigDF
# Out:
#                                       GHI         DNI  Wind Speed  \
# Date       Latitude Longitude
# 2018-01-01 18.20    -67.29     177.291667  185.062500    5.061458
#                     -67.27     177.781250  182.291667    5.014583
#                     -67.25     180.625000  190.416667    4.955208
#                     -67.23     174.656250  178.447917    4.882292
#                     -67.21     175.937500  182.343750    4.812500
# ...                                   ...         ...         ...
# 2018-12-31 18.52    -66.47     198.104167  271.250000    4.667708
#                     -66.45     200.281250  277.000000    4.667708
#                     -66.43     200.072917  273.593750    4.659375
#                     -66.41     206.677083  289.260417    4.655208
#                     -66.39     199.666667  272.187500    4.653125
#
#                                Temperature  Relative Humidity
# Date       Latitude Longitude
# 2018-01-01 18.20    -67.29       26.985417          78.896667
#                     -67.27       26.985417          78.801875
#                     -67.25       26.982292          78.716979
#                     -67.23       26.978125          78.633021
#                     -67.21       26.973958          78.546146
# ...                                    ...                ...
# 2018-12-31 18.52    -66.47       26.321875          73.957500
#                     -66.45       26.311458          73.960000
#                     -66.43       26.301042          73.966979
#                     -66.41       26.294792          73.958021
#                     -66.39       26.291667          73.934583
#
# [284700 rows x 5 columns]

# %%
test_group_df2 = BigDF.groupby([pd.Grouper(level="Date", freq='1D'),"Latitude","Longitude"]).mean()
test_group_df2
# Out:
#                                       GHI         DNI  Wind Speed  \
# Date       Latitude Longitude
# 2018-01-01 18.20    -67.29     177.291667  185.062500    5.061458
#                     -67.27     177.781250  182.291667    5.014583
#                     -67.25     180.625000  190.416667    4.955208
#                     -67.23     174.656250  178.447917    4.882292
#                     -67.21     175.937500  182.343750    4.812500
# ...                                   ...         ...         ...
# 2018-12-31 18.52    -66.47     198.104167  271.250000    4.667708
#                     -66.45     200.281250  277.000000    4.667708
#                     -66.43     200.072917  273.593750    4.659375
#                     -66.41     206.677083  289.260417    4.655208
#                     -66.39     199.666667  272.187500    4.653125
#
#                                Temperature  Relative Humidity
# Date       Latitude Longitude
# 2018-01-01 18.20    -67.29       26.985417          78.896667
#                     -67.27       26.985417          78.801875
#                     -67.25       26.982292          78.716979
#                     -67.23       26.978125          78.633021
#                     -67.21       26.973958          78.546146
# ...                                    ...                ...
# 2018-12-31 18.52    -66.47       26.321875          73.957500
#                     -66.45       26.311458          73.960000
#                     -66.43       26.301042          73.966979
#                     -66.41       26.294792          73.958021
#                     -66.39       26.291667          73.934583
#
# [284700 rows x 5 columns]

# %%
d1 = display2.iloc[:1]
d2 = display2.iloc[2:]
# display2.iloc[1]

## Next step is figure out a possible lambda function to create the new date column and datetime object after which dataframe will be ready to move on to the next step of parsing.

d2 = d2.rename(columns=display2.loc[1]).dropna(axis=1)
d2
d2['Date'] = pd.to_datetime(d2['Year']+" "+d2['Month']+" "+d2['Day']+" "+d2['Hour']+" "+d2['Minute'],format="%Y %m %d %H %M")

d2 = d2.drop(columns=['Year','Month','Day','Hour','Minute'])


## research about possible list slicing for automating the reorganizing. Evaluate if truly necessary
cols = list(d2.columns)
cols = [cols[-1]]  + cols[:-1]
d2 = d2[cols]
d2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23024/1605011688.py in <module>
#       5 ## Next step is figure out a possible lambda function to create the new date column and datetime object after which dataframe will be ready to move on to the next step of parsing.
#       6
# ----> 7 d2 = d2.rename(columns=test_group_df2.loc[1]).dropna(axis=1)
#       8 d2
#       9 d2['Date'] = pd.to_datetime(d2['Year']+" "+d2['Month']+" "+d2['Day']+" "+d2['Hour']+" "+d2['Minute'],format="%Y %m %d %H %M")
#
# D:\Users\viaje\anaconda3\envs\solarData\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# D:\Users\viaje\anaconda3\envs\solarData\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# D:\Users\viaje\anaconda3\envs\solarData\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
# -> 1113         return self.obj.xs(label, axis=axis)
#    1114
#    1115     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# D:\Users\viaje\anaconda3\envs\solarData\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3768         if isinstance(index, MultiIndex):
#    3769             try:
# -> 3770                 loc, new_index = index._get_loc_level(
#    3771                     key, level=0, drop_level=drop_level
#    3772                 )
#
# D:\Users\viaje\anaconda3\envs\solarData\lib\site-packages\pandas\core\indexes\multi.py in _get_loc_level(self, key, level, drop_level)
#    3110                 return indexer, maybe_mi_droplevels(indexer, ilevels, drop_level)
#    3111         else:
# -> 3112             indexer = self._get_level_indexer(key, level=level)
#    3113             return indexer, maybe_mi_droplevels(indexer, [level], drop_level)
#    3114
#
# D:\Users\viaje\anaconda3\envs\solarData\lib\site-packages\pandas\core\indexes\multi.py in _get_level_indexer(self, key, level, indexer)
#    3202         else:
#    3203
# -> 3204             idx = self._get_loc_single_level_index(level_index, key)
#    3205
#    3206             if level > 0 or self._lexsort_depth == 0:
#
# D:\Users\viaje\anaconda3\envs\solarData\lib\site-packages\pandas\core\indexes\multi.py in _get_loc_single_level_index(self, level_index, key)
#    2853             return -1
#    2854         else:
# -> 2855             return level_index.get_loc(key)
#    2856
#    2857     def get_loc(self, key, method=None):
#
# D:\Users\viaje\anaconda3\envs\solarData\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#     698         else:
#     699             # unrecognized type
# --> 700             raise KeyError(key)
#     701
#     702         try:
#
# KeyError: 1

# %%
for rowIndex, row in  test_group_df.iterrows():
    # print(rowIndex[1],rowIndex[2],row['GHI'])
    GHIData = pd.DataFrame(data={'value': [row['GHI']],'Latitude': [rowIndex[1]],'Longitude': [rowIndex[2]]})
    AirTempData = pd.DataFrame(data={'value': [row['Air Temperature']],'Latitude': [rowIndex[1]],'Longitude': [rowIndex[2]]})
    DNIData = pd.DataFrame(data={'value': [row['DNI']],'Latitude': [rowIndex[1]],'Longitude': [rowIndex[2]]})
    WindSpeedData = pd.DataFrame(data={'value': [row['Wind Speed']],'Latitude': [rowIndex[1]],'Longitude': [rowIndex[2]]})
    # RelHumData = pd.DataFrame(data={'value': [row['Relative Humidity']],'Latitude': [rowIndex[1]],'Longitude': [rowIndex[2]]})
    GHIData.to_csv(path_or_buf=f"../Test Data/GHI/GHI{rowIndex[0].strftime('%Y%j')}",header=False,index=False,sep=' ')
    AirTempData.to_csv(path_or_buf=f"../Test Data/AirTemp/AirTemperature{rowIndex[0].strftime('%Y%j')}",header=False,index=False,sep=' ')
    DNIData .to_csv(path_or_buf=f"../Test Data/DNI/DNI{rowIndex[0].strftime('%Y%j')}",header=False,index=False,sep=' ')
    WindSpeedData.to_csv(path_or_buf=f"../Test Data/WindSpeed/WindSpeed{rowIndex[0].strftime('%Y%j')}",header=False,index=False,sep=' ')
    # RelHumData.to_csv(path_or_buf=f"../Test Data/RelHum/RelativeHumidity{rowIndex[0].strftime('%Y%j')}",header=False,index=False,sep=' ')

# %%
data_dir = "..\\Data\\"


def make_dir(Year,Directory_names):
    """
    Will take in a list of the directory names to create and then will proceed to generate the directories
     _____________________________________

    Parameters: 

    Directory_names:  This is a list that must contain all of the names that will be used to create the desired directories within the Data directory.
    """

    for name in Directory_names:
        if not os.path.isdir(data_dir+Year+name):
            print(data_dir+Year+name)
            os.makedirs(data_dir+Year+name)
        else:
            continue

# %%
make_dir("2019",["GHI","DNI"])
# Out:
# ..\Data\2019GHI
# ..\Data\2019DNI
